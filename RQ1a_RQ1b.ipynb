# %%
from src.plot_functions import create_demographic_plot, create_gender_odds_ratio_heatmap, create_language_specific_age_plot
from src.prepare_data import load_data_for_demographic
from src.prepare_data import parties, party_colors, languages

# %%
df = load_data_for_demographic(data_folder='data')
# Out:
# 40044
# 34559

# %%
create_demographic_plot(df, parties=parties, party_colors=party_colors)

# %%
create_gender_odds_ratio_heatmap(df[['demographic_distribution', 'impressions_lower', 'impressions_upper', 'party_name', 'lang']], parties=parties, party_colors=party_colors, languages=languages, n_bootstrap=100, output_dir='imgs', save=False)

# %%
create_language_specific_age_plot(df = df[['demographic_distribution', 'impressions_lower', 'impressions_upper', 'party_name', 'lang']], parties = parties, party_colors=party_colors, languages = ['DE', 'FR', 'IT'], save=False)
