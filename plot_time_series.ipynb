# %%
from src.prepare_data import load_data_for_demographic, get_referendums
from src.prepare_data import parties, party_colors, languages

# %%
from src.plot_functions import plot_impressions_time_series

# %%
df = load_data_for_demographic(data_folder='data')
# Out:
# 40044
# 34559

# %%
referendums = get_referendums(data_folder='data')
len(referendums)
# Out:
# 22

# %%
plot_impressions_time_series(df, output_dir='imgs', save=False, event_dates=referendums, show_plot=True, inset_pos_size=[0.127, 0.45, 0.35, 0.5])
# Out:
# 3605741.5
# limit!
# 3499.5
# 4758956.5
